# %%
import pandas as pd
import numpy as np
import datasets
from datasets import load_dataset
import pickle
import os

print("Current Working Directory: ", os.getcwd())

#data = load_dataset("common_language", download_mode="reuse_dataset_if_exists")
#print(data['train'])
# Out:
# Current Working Directory:  c:\Users\simon\Documents\Universite - Hiver 2024\STT3795 - Sciences des données\Projet-STT-3795\src

# %%
import pickle
import os

print("Current Working Directory: ", os.getcwd())

#Save 
#with open('dataframes.pkl', 'wb') as handle:
#    pickle.dump(dataframes, handle, protocol=pickle.HIGHEST_PROTOCOL)

#Read
#with open('path/to/save/dataframes.pkl', 'rb') as handle:
#    dataframes = pickle.load(handle)

#dataframes['train']['audio'][0]['path']
#for key, df in dataframes.items():
#    df.to_parquet(f'src/data/{key}_dataset.parquet')
# Out:
# Current Working Directory:  c:\Users\simon\Documents\Universite - Hiver 2024\STT3795 - Sciences des données\Projet-STT-3795\src

# %%
with open('dataframes.pkl', 'rb') as handle:
    dataframes = pickle.load(handle)

dataframes['train']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 with open('dataframes.pkl', 'rb') as handle:
#       2     dataframes = pickle.load(handle)
#       4 dataframes['train']
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataframes.pkl'

# %%
dataframes['test']
# Out:
#           client_id                                               path  \
# 0     ara_tst_sp_26  /storage/hf-datasets-cache/medium/datasets/601...
# 1     ara_tst_sp_16  /storage/hf-datasets-cache/medium/datasets/601...
# 2     ara_tst_sp_14  /storage/hf-datasets-cache/medium/datasets/601...
# 3     ara_tst_sp_15  /storage/hf-datasets-cache/medium/datasets/601...
# 4      ara_tst_sp_4  /storage/hf-datasets-cache/medium/datasets/601...
# ...             ...                                                ...
# 5958  wls_tst_sp_24  /storage/hf-datasets-cache/medium/datasets/601...
# 5959  wls_tst_sp_24  /storage/hf-datasets-cache/medium/datasets/601...
# 5960   wls_tst_sp_5  /storage/hf-datasets-cache/medium/datasets/601...
# 5961  wls_tst_sp_24  /storage/hf-datasets-cache/medium/datasets/601...
# 5962   wls_tst_sp_4  /storage/hf-datasets-cache/medium/datasets/601...
#
#                                                   audio  \
# 0     {'bytes': b'RIFF$\xa7\x01\x00WAVEfmt \x10\x00\...
# 1     {'bytes': b'RIFF$\x01\x02\x00WAVEfmt \x10\x00\...
# 2     {'bytes': b'RIFF$t\x01\x00WAVEfmt \x10\x00\x00...
# 3     {'bytes': b'RIFF$\x1e\x03\x00WAVEfmt \x10\x00\...
# 4     {'bytes': b'RIFF$e\x01\x00WAVEfmt \x10\x00\x00...
# ...                                                 ...
# 5958  {'bytes': b'RIFF$\x83\x04\x00WAVEfmt \x10\x00\...
# 5959  {'bytes': b'RIFF$\xf4\x02\x00WAVEfmt \x10\x00\...
# 5960  {'bytes': b'RIFF$b\x04\x00WAVEfmt \x10\x00\x00...
# 5961  {'bytes': b'RIFF$9\x03\x00WAVEfmt \x10\x00\x00...
# 5962  {'bytes': b'RIFF$l\x03\x00WAVEfmt \x10\x00\x00...
#
#                                                sentence          age  \
# 0                                       لا بد أنك تمزح!     twenties
# 1                                 ماذا هناك في حقيبتك ؟     twenties
# 2                                    لا أحد يملك القمر.     twenties
# 3                       كلا الطالبين لم ينجحا الإختبار.  not_defined
# 4                                         القلعة جميلة.  not_defined
# ...                                                 ...          ...
# 5958  Yna cymerodd gwrs ysgrifennu ôl radd yn yr Ysg...  not_defined
# 5959  Wedi ymadael â'r ysgol bu'n gweithio yn y gwai...  not_defined
# 5960  Cyn pen yr hanner awr, yr oeddem yn eistedd ar...  not_defined
# 5961  Cafodd Barnes ei eni yn Aberhonddu i rieni o L...  not_defined
# 5962  Yr oedd gan Wil galon agored a charedig, ac ys...     twenties
#
#            gender  language
# 0            male         0
# 1            male         0
# 2            male         0
# 3     not_defined         0
# 4     not_defined         0
# ...           ...       ...
# 5958  not_defined        44
# 5959  not_defined        44
# 5960  not_defined        44
# 5961  not_defined        44
# 5962         male        44
#
# [5963 rows x 7 columns]

# %%
dataframes['test']['audio'][0]
# Out:
# {'bytes': b'RIFF$\xa7\x01\x00WAVEfmt \x10\x00\x00\x00\x01\x00\x01\x00\x80>\x00\x00\x00}\x00\x00\x02\x00\x10\x00data\ ...
#  'path': 'common_voice_ar_19203953.wav'}

# %%
print("Current Working Directory: ", os.getcwd())
# Out:
# Current Working Directory:  c:\Users\Kamen\ML\Projet-STT-3795\src\data

# %%
def save_audio_file(entry, save_directory):
    """
    Saves an audio file from the given entry to the specified directory.

    :param entry: A dictionary with 'bytes' containing the audio data and 'path' the filename.
    :param save_directory: The directory where the audio file will be saved.
    """
    # Extract the audio bytes and the filename from the entry
    audio_bytes = entry['bytes']
    filename = entry['path']
    
    # Ensure the save directory exists
    os.makedirs(save_directory, exist_ok=True)
    
    # Construct the full path for saving the audio file
    file_path = os.path.join(save_directory, filename)
    
    # Write the audio bytes to the file
    with open(file_path, 'wb') as audio_file:
        audio_file.write(audio_bytes)

# %%
for d in ['train', 'validation', 'test']:
    save_directory = 'wav_files/' + d 
    for entry in dataframes[d]['audio']:
        save_audio_file(entry, save_directory)
        break

# %%
dataframes['train'][-1000:-900]
# Out:
#             client_id                                               path  \
# 21194   trk_trn_sp_12  /storage/hf-datasets-cache/medium/datasets/601...
# 21195   trk_trn_sp_20  /storage/hf-datasets-cache/medium/datasets/601...
# 21196  trk_trn_sp_196  /storage/hf-datasets-cache/medium/datasets/601...
# 21197   trk_trn_sp_87  /storage/hf-datasets-cache/medium/datasets/601...
# 21198  trk_trn_sp_409  /storage/hf-datasets-cache/medium/datasets/601...
# ...               ...                                                ...
# 21289  ukr_trn_sp_127  /storage/hf-datasets-cache/medium/datasets/601...
# 21290  ukr_trn_sp_163  /storage/hf-datasets-cache/medium/datasets/601...
# 21291  ukr_trn_sp_106  /storage/hf-datasets-cache/medium/datasets/601...
# 21292  ukr_trn_sp_163  /storage/hf-datasets-cache/medium/datasets/601...
# 21293   ukr_trn_sp_11  /storage/hf-datasets-cache/medium/datasets/601...
#
#                                                    audio  \
# 21194  {'bytes': b'RIFF$\xa4\x01\x00WAVEfmt \x10\x00\...
# 21195  {'bytes': b'RIFF$k\x01\x00WAVEfmt \x10\x00\x00...
# 21196  {'bytes': b'RIFF$y\x02\x00WAVEfmt \x10\x00\x00...
# 21197  {'bytes': b'RIFF$\xeb\x02\x00WAVEfmt \x10\x00\...
# 21198  {'bytes': b'RIFF$\xb6\x01\x00WAVEfmt \x10\x00\...
# ...                                                  ...
# 21289  {'bytes': b'RIFF$\xa6\x02\x00WAVEfmt \x10\x00\...
# 21290  {'bytes': b'RIFF$\xd4\x01\x00WAVEfmt \x10\x00\...
# 21291  {'bytes': b'RIFF$\xec\x01\x00WAVEfmt \x10\x00\...
# 21292  {'bytes': b'RIFF$\xce\x01\x00WAVEfmt \x10\x00\...
# 21293  {'bytes': b'RIFF$\xdc\x02\x00WAVEfmt \x10\x00\...
#
#                                                 sentence          age  \
# 21194                    Gazprom da bu projeye dahil mi?        teens
# 21195               Bazılar iyi bir neden için koştular.  not_defined
# 21196  Balkanlar yaşanan bu felakete anında yanıt verdi.  not_defined
# 21197                         Kasedin etkisi büyük oldu.  not_defined
# 21198           Yeni yasa uyarınca bunlar da kaldırıldı.     twenties
# ...                                                  ...          ...
# 21289                провал діяльності нового парламенту  not_defined
# 21290                                  Ну, бог з вами...     thirties
# 21291  У Токіо відбувся один із найбільших конкурсів ...        teens
# 21292                         прошу ближче до мікрофону!     thirties
# 21293  Найкраще люди розбираються в тому, чого в них ...     thirties
#
#             gender  language
# 21194         male        42
# 21195  not_defined        42
# 21196  not_defined        42
# 21197  not_defined        42
# 21198         male        42
# ...            ...       ...
# 21289  not_defined        43
# 21290       female        43
# 21291         male        43
# 21292       female        43
# 21293         male        43
#
# [100 rows x 7 columns]

# %%
languages = "Arabic, Basque, Breton, Catalan, Chinese_China, Chinese_Hongkong, Chinese_Taiwan, Chuvash, Czech, Dhivehi, Dutch, English, Esperanto, Estonian, French, Frisian, Georgian, German, Greek, Hakha_Chin, Indonesian, Interlingua, Italian, Japanese, Kabyle, Kinyarwanda, Kyrgyz, Latvian, Maltese, Mongolian, Persian, Polish, Portuguese, Romanian, Romansh_Sursilvan, Russian, Sakha, Slovenian, Spanish, Swedish, Tamil, Tatar, Turkish, Ukranian, Welsh".split(", ")
mapper = {i: languages[i] for i in range(len(languages))}
for d in ['train', 'test', 'validation']: 
    dataframes[d]['language'] = dataframes[d]['language'].map(mapper)

# %%
import matplotlib.pyplot as plt
split_types = ['train', 'test', 'validation']
for d in split_types:
    print("Central tendency metrics for " + d)
    vector = dataframes[d].groupby('language').count()['path']
    print("Min : " + str(min(vector)))
    print("Max: " + str(max(vector)))
    print("Mean : " + str(np.mean(vector)))
    print("Median : " + str(np.median(vector)))
    plt.figure(figsize=(10, 6))  # Optional: Adjust the size of the plot
    vector.plot(kind='bar')
    plt.title('Bar Chart of column_name')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.xticks(rotation=90)  # Rotate x-axis labels to make them readable
    plt.show()
    print("\n")

#Dsitribution are more or uniformally distributed. No need to further randomize the splits
# Out:
# Central tendency metrics for train
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       3 for d in split_types:
#       4     print("Central tendency metrics for " + d)
# ----> 5     vector = dataframes[d].groupby('language').count()['path']
#       6     print("Min : " + str(min(vector)))
#       7     print("Max: " + str(max(vector)))
#
# NameError: name 'dataframes' is not defined

# %%
#Idea: Try classification task only with audio files and, then try classification with age and gender and audio file.

#Data processing idea, keep categorical data in csv format
